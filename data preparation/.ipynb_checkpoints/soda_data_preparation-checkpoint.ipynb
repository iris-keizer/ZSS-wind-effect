# %% [markdown]
# ## Notebook to prepare SODA data to obtain the wind effect
#
#
# SODA data is downloaded from:

# %%
import xarray as xr
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ### Import data

# %%
path = '/Users/iriskeizer/Documents/Zeespiegelscenarios/data/soda/raw'

data = xr.open_mfdataset(f'{path}/*.nc')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 492, xt_ocean: 720, yt_ocean: 330, xu_ocean: 720,
#                   yu_ocean: 330, st_ocean: 50, sw_ocean: 50)
# Coordinates:
#   * time         (time) datetime64[ns] 1980-01-16T01:00:00 ... 2020-12-13T13:...
#   * xt_ocean     (xt_ocean) float64 0.25 0.75 1.25 1.75 ... 358.8 359.2 359.8
#   * yt_ocean     (yt_ocean) float64 -74.75 -74.25 -73.75 ... 88.75 89.25 89.75
#   * xu_ocean     (xu_ocean) float64 0.5 1.0 1.5 2.0 ... 358.5 359.0 359.5 360.0
#   * yu_ocean     (yu_ocean) float64 -74.5 -74.0 -73.5 -73.0 ... 89.0 89.5 90.0
#   * st_ocean     (st_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
#   * sw_ocean     (sw_ocean) float64 5.034 15.1 25.22 ... 5.185e+03 5.395e+03
# Data variables: (12/13)
#     temp         (time, st_ocean, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 50, 330, 720), meta=np.ndarray>
#     salt         (time, st_ocean, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 50, 330, 720), meta=np.ndarray>
#     wt           (time, sw_ocean, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 50, 330, 720), meta=np.ndarray>
#     ssh          (time, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 330, 720), meta=np.ndarray>
#     mlt          (time, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 330, 720), meta=np.ndarray>
#     mlp          (time, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 330, 720), meta=np.ndarray>
#     ...           ...
#     net_heating  (time, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 330, 720), meta=np.ndarray>
#     prho         (time, st_ocean, yt_ocean, xt_ocean) float32 dask.array<chunksize=(12, 50, 330, 720), meta=np.ndarray>
#     u            (time, st_ocean, yu_ocean, xu_ocean) float32 dask.array<chunksize=(12, 50, 330, 720), meta=np.ndarray>
#     v            (time, st_ocean, yu_ocean, xu_ocean) float32 dask.array<chunksize=(12, 50, 330, 720), meta=np.ndarray>
#     taux         (time, yu_ocean, xu_ocean) float32 dask.array<chunksize=(12, 330, 720), meta=np.ndarray>
#     tauy         (time, yu_ocean, xu_ocean) float32 dask.array<chunksize=(12, 330, 720), meta=np.ndarray>
# Attributes:
#     CDI:                       Climate Data Interface version 1.9.2 (http://m...
#     Conventions:               CF-1.6
#     history:                   Tue Nov  6 14:21:13 2018: ncrcat /aosc/greenla...
#     filename:                  ./regrid_MOM2SODA.nc
#     title:                     MOM5_SODA_3.4.2
#     grid_type:                 mosaic
#     grid_tile:                 1
#     CDO:                       Climate Data Operators version 1.9.2 (http://m...
#     nco_openmp_thread_number:  1

# %% [markdown]
# ### Data preparations

# %% [markdown]
# #### Remove unnecessary variables

# %%
data = data.drop(['temp', 'salt', 'wt', 'mlt', 'mlp', 'mls', 'net_heating', 'prho', 'u', 'v', 'taux', 'tauy',
                 'xu_ocean', 'yu_ocean', 'st_ocean', 'sw_ocean'])

# %% [markdown]
# #### Remove global mean SSH from data

# %%
# Obtain regionally averaged global mean SSH
weights = np.cos(np.deg2rad(data.yt_ocean))
data_weighted = data.weighted(weights)

ssh_global = data_weighted.mean(['xt_ocean', 'yt_ocean'])

# Remove global SSH from soda sea-level signal
data['ssh'] = data['ssh'] - ssh_global.ssh

# %% [markdown]
# #### Obtain annual averages

# %%
data = data.groupby('time.year').mean('time').rename({'year':'time'})

# %% [markdown]
# #### Select data near tide gauge stations

# %%
stations = ['Vlissingen', 'Hoek v. Holland', 'Den Helder', 'Delfzijl', 'Harlingen', 'IJmuiden', 'Average']


def station_coords(): 
    """
    Function to obtain the coordinates of the tide gauge stations as a dataframe
    
    """
    
    
    # Necessary declarations to obtain tide gauge station coordinates
    path_locations = '/Users/iriskeizer/Documents/Zeespiegelscenarios/data/rlr_annual/filelist.txt'
    loc_num = [20, 22, 23, 24, 25, 32]
    col_names = ['id', 'lat', 'lon', 'name', 'coastline_code', 'station_code', 'quality']
    
    # Create dataframe
    df = pd.read_csv(path_locations, sep=';', header=None, names=col_names)
    df = df.set_index('id')
    df = df.loc[loc_num, :]
    df['name'] = stations[:-1]
    df = df.set_index('name')
    df = df.drop(['coastline_code', 'station_code', 'quality'], axis=1)
    
    return df


coord_df = station_coords()

# %%
data_df = pd.DataFrame({'time' : data.time.data}).set_index('time')

for station in coord_df.index:
    data_df[station] = data.sel(xt_ocean = coord_df['lon'][station], yt_ocean = coord_df['lat'][station], method = 'Nearest').ssh.data
    
data_df['Average'] = df.mean(axis=1)

# %%
data_df.plot()
plt.ylabel('Sea level [m]')
plt.xlabel('Time [yr]')
# Out:
# Text(0.5, 0, 'Time [yr]')

# %% [markdown]
# #### Save DataFrame

# %%
path = '/Users/iriskeizer/Documents/Zeespiegelscenarios/data/soda/regression input'

data_df.to_csv(f'{path}/sealevel_soda.csv')

# %% [markdown]
# The IBE has not been removed
